# %% [markdown]
# ***
# # Exercise: Regular Expressions
# ***

# %% [markdown]
# *By Asmik Nalmpatian and Lisa Wimmer – for Intro to NLP*

# %% [markdown]
# ![Logo_Consulting.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## Set-up

# %% [markdown]
# Check: `Runtime type = R`?
#
# ➡ If not, re-launch Google Colab via https://colab.to/r and upload this notebook there.

# %% [markdown]
# ## Exercise 1: Use Regular Expressions
#
# You see some sentences extracted from Tom's and Monica's notebooks.

# %%
text <- c(
  "Tom has visited 20 countries",
  "Tom only has eight fingers.",
  "Tom has worked at ten different jobs",
  "Monica can speak 6 languages",
  "tom's favorite food is pasta",
  "Tom can name 13 facts about himself.",
  "Tom's favorite two colors are orange and green",
  "Monica's favorite number is 8888.",
  "Tom lives at Leopoldstr. 12, Munich",
  "He is 8 feet tall",
  "Monica says hi!",
  "Monica secretly likes Tom.")

# %% [markdown]
# *Packages*

# %%
# Install all required packages:

# ...

# %%
# Load all required packages:

# ...

# %% [markdown]
# ### Exercise 1.1
#
# Print each numeric number that is contained in the text.

# %%
# _____________(string = text, pattern = "_____________")

# ...

# %% [markdown]
# ### Exercise 1.2
#
# Find all items with a number followed by a space.

# %%
# _____________(string = text, pattern = "_____________")

# ...

# %% [markdown]
# ### Exercise 1.3
#
# How many times did they write down 'favorite'?

# %%
# sum(_____________(string = text, pattern = "_____________"))

# ...

# %% [markdown]
# ### Exercise 1.4
#
# Replace all punctuation symbols in the text with the word "PUNCT".

# %%
# _____________(string = text, pattern = "_____________")

# ...

# %% [markdown]
# ### Exercise 1.5
#
# Lastly, find all sentences *starting* with "Tom" (i.e., the last sentence should not be matched).

# %%
# _____________(string = text, pattern = "_____________")

# ...

# %% [markdown]
# ## Exercise 2: Write Regular Expressions

# %% [markdown]
# ### Exercise 2.1
#
# Create a regular expression that will match the mobile numbers as commonly written in Germany (omitting the country code, separating the first four digits from the rest by a hyphen, i.e., "01xx-...").

# %%
# Only the first element of the following vector should be matched:

potential_numbers <- c(
  "0176-33665544", 
  "(123)456-7890", 
  "(123) 456-7890", 
  "123-2351")

# %%
# Fill in your pattern (again, there are several valid ways). 

# mobile_pattern <- "_____________"

# ...

# %%
# Check whether your pattern works fine

# _____________(string = potential_numbers, pattern = mobile_pattern)

# ...

# %% [markdown]
# ### Exercise 2.2
#
# Now allow for the first 0 to be omitted, i.e., make the leading 0 optional.
# Your pattern should now also match the last number.

# %%
# Fill in your pattern (again, there are several valid ways). 

# mobile_pattern_flexible <- "_____________"

# ...

# %%
# Check whether your pattern works fine

# _____________(string = potential_numbers, pattern = mobile_pattern_flexible)

# ...
