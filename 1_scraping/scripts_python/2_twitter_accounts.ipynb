# %% [markdown]
# # Scraping Twitter accounts from party websites

# %% [markdown]
# Note: In case of the AfD party, Twitter accounts are not available on the official party website and must thus be gathered manually.

# %% [markdown]
# ### Prerequisites

# %%
# Libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import pickle
import numpy as np
import unidecode
import os
import ctypes

# %%
# Define user path (comment out the irrelevant one) and set working directory

my_path = 'C:\\Users\\wimme\\Documents\\1_uni\\1_master\\consulting\\projects\\consulting\\1_scraping'
# my_path = 'Asmiks path'
os.chdir(my_path)
os.path.abspath(os.getcwd())
# Out:
# 'C:\\Users\\wimme\\Documents\\1_uni\\1_master\\consulting\\projects\\consulting\\1_scraping'

# %% [markdown]
# ### Setup

# %%
# Access party websites and convert into soups 

fdp = "https://www.fdpbt.de/fraktion/abgeordnete"
source_fdp = requests.get(fdp).text
soup_fdp = BeautifulSoup(source_fdp, 'html.parser')

cdu = "https://www.cducsu.de/hier-stellt-die-cducsu-bundestagsfraktion-ihre-abgeordneten-vor"
source_cdu = requests.get(cdu).text
soup_cdu = BeautifulSoup(source_cdu, 'html.parser')

spd = "https://www.spdfraktion.de/abgeordnete/alle?wp=19&view=list&old=19"
source_spd = requests.get(spd).text
soup_spd = BeautifulSoup(source_spd, 'html.parser')

gruene = "https://www.gruene-bundestag.de/abgeordnete"
source_gruene = requests.get(gruene).text
soup_gruene = BeautifulSoup(source_gruene, 'html.parser')

# For Die Linke, one needs to extract Twitter accounts from each individual MP website
linke_base = "https://www.linksfraktion.de/fraktion/abgeordnete/"
# Website contains bins of MPs, according to last name
letters = [['a', 'e'], ['f', 'j'], ['k', 'o'], ['p', 't'], ['u', 'z']] 
linke_name_bins = []

for letter in letters:
    extension = f'{letter[0]}-bis-{letter[1]}/' 
    linke_name_bins.append(linke_base + extension)

# %%
# For each party, find appropriate parent node in soup

# all_abg_fdp = soup_fdp.find(class_ = 'person-list').find_all(class_ = 'person-item-wrapper')

all_abg_cdu = soup_cdu.find_all(class_ = 'teaser delegates')

all_abg_spd = soup_spd.find_all(class_ = 'views-row')

extensions_gruene = soup_gruene.find_all('a', class_ = "abgeordneteTeaser__wrapper")
urlbase_gruene = 'https://www.gruene-bundestag.de'
all_abg_gruene = []

for a in extensions_gruene:
    
    extension = a['href']
    link = urlbase_gruene + str(extension)
    all_abg_gruene.append(link)
    
all_abg_linke = []

for name_bin in linke_name_bins:
    
    source = requests.get(name_bin).text
    soup = BeautifulSoup(source, 'html.parser')
    
    for abg in soup.find_all('div', attrs = {'class': 'col-xs-12 col-sm-12 col-md-6 col-lg-6'}):
        extension = abg.find('h2').find('a')['href'].lstrip('/fraktion/abgeordnete/')
        all_abg_linke.append(linke_base + extension)

# %% [markdown]
# ### Scraping

# %%
# Scrape accounts from soups 

twitter_list = []

# CDU/CSU

for abg in all_abg_cdu:
    
    twitter = abg.find(class_ = 'twitter')
    
    twitter_list.append(
        {
            'party': "CDU/CSU",
            'name': abg.find('h2').find('span').text.strip(' '),
            'twitter_ext': twitter.find('a', href = True)['href'] if twitter is not None else ""
        }
    )

# FDP

# for abg in all_abg_fdp:
    
#     name_field = abg.find(class_ = 'person-name')
#     funktion = name_field.find('span').text.strip()
#     name = name_field.text.strip('\n').strip().rstrip(funktion).strip('\n').strip()
#     twitter = abg.find('a', attrs = {'class': 'tw'}, href = True)
    
#     twitter_list.append(
#         {
#             'party': "FDP",
#             'name': name,
#             'twitter_ext': twitter['href'] if twitter is not None else ""
#         }
#     )

# Gruene

for abg in all_abg_gruene:
    
    abg_source = requests.get(abg).text
    abg_soup = BeautifulSoup(abg_source, 'html.parser')
    hrefss = []
    twitter = ""
    
    for x in abg_soup.find_all(class_ = "weitereInfoTeaser"):
        
        for y in x.find_all('a', href = True):
            
            z = y['href']
            hrefss.append(z)
            
            for i in hrefss:
                
                if "twitter" not in i:
                    continue 
                else:
                    twitter = i
                    
    twitter_list.append(           
        {
            'party': "Bündnis 90/Die Grünen",
            'name': abg_soup.find('h1').text,
            'twitter_ext': twitter
        }
    )
    
# Linke

for abg in all_abg_linke:
    
    abg_source = requests.get(abg).text
    abg_soup = BeautifulSoup(abg_source, 'html.parser')
    twitter = abg_soup.find('a', text = re.compile('Twitter-Profil'))
    
    twitter_list.append(
        {
            'party': "Die Linke",
            'name': abg_soup.find('h1').text.strip(' '),
            'twitter_ext': twitter['href'] if twitter is not None else ""
        }
    )

# SPD

for abg in all_abg_spd:
    
    twitter = abg.find(class_ = 'ico_twitter')
    
    twitter_list.append(
        {
            'party': "SPD",
            'name': abg.find('h3').find('a').get_text().strip(' '),
            'twitter_ext': twitter['href'] if twitter is not None else ""
        }
    )
    
# Convert to data frame    
    
twitter_df = pd.DataFrame(twitter_list)    

ctypes.windll.user32.MessageBoxW(0, "Twitter accounts successfully scraped", "Progress Report")
# Out:
# 1

# %%
twitter_df.head()
# Out:
#      party                      name                       twitter_ext
# 0  CDU/CSU  Dr. Michael von Abercron    https://twitter.com/mvabercron
# 1  CDU/CSU            Stephan Albani
# 2  CDU/CSU         Norbert Altenkamp
# 3  CDU/CSU            Peter Altmaier  http://twitter.com/peteraltmaier
# 4  CDU/CSU            Philipp Amthor

# %%
# Add list of manually collected account names for AfD

afd_df = pd.read_csv('input/afd_twitter_accounts.csv', encoding = "ISO-8859-1", delimiter = ';')
afd_df.columns = ['name', 'party', 'twitter_ext']
columns_titles = ['party', 'name', 'twitter_ext']
afd_df = afd_df.reindex(columns = columns_titles)

twitter_df = twitter_df.append(afd_df)

# %%
twitter_df
# Out:
#       party                      name                       twitter_ext
# 0   CDU/CSU  Dr. Michael von Abercron    https://twitter.com/mvabercron
# 1   CDU/CSU            Stephan Albani
# 2   CDU/CSU         Norbert Altenkamp
# 3   CDU/CSU            Peter Altmaier  http://twitter.com/peteraltmaier
# 4   CDU/CSU            Philipp Amthor
# ..      ...                       ...                               ...
# 84      AfD    Prof. Dr. Harald Weyel                           h_weyel
# 85      AfD           Wolfgang Wiehle                    WolfgangWiehle
# 86      AfD        Dr. Heiko Wildberg                    Heiko_Wildberg
# 87      AfD       Dr. Christian Wirth                       ChrWirthMdB
# 88      AfD                  Uwe Witt                          Witt_Uwe
#
# [637 rows x 3 columns]

# %%
twitter_df[twitter_df['party'] == 'CDU/CSU'].head(50)
# Out:
#       party                      name                           twitter_ext
# 0   CDU/CSU  Dr. Michael von Abercron        https://twitter.com/mvabercron
# 1   CDU/CSU            Stephan Albani
# 2   CDU/CSU         Norbert Altenkamp
# 3   CDU/CSU            Peter Altmaier      http://twitter.com/peteraltmaier
# 4   CDU/CSU            Philipp Amthor
# 5   CDU/CSU         Artur Auernhammer
# 6   CDU/CSU               Peter Aumer        https://twitter.com/PeterAumer
# 7   CDU/CSU              Dorothee Bär           http://twitter.com/DoroBaer
# 8   CDU/CSU             Thomas Bareiß    https://twitter.com/Thomas_Bareiss
# 9   CDU/CSU           Norbert Barthle
# 10  CDU/CSU             Maik Beermann      https://twitter.com/MaikBeermann
# 11  CDU/CSU           Manfred Behrens     http://twitter.com/Manfredbehrens
# 12  CDU/CSU         Veronika Bellmann
# 13  CDU/CSU           Sybille Benning    https://twitter.com/SybilleBenning
# 14  CDU/CSU      Dr. André Berghegger
# 15  CDU/CSU         Melanie Bernstein
# 16  CDU/CSU       Christoph Bernstiel       https://twitter.com/c_bernstiel
# 17  CDU/CSU               Peter Beyer       https://twitter.com/Peter_Beyer
# 18  CDU/CSU              Marc Biadacz       https://twitter.com/MBiadaczMdB
# 19  CDU/CSU            Steffen Bilger      http://twitter.com/steffenbilger
# 20  CDU/CSU              Peter Bleser
# 21  CDU/CSU         Norbert Brackmann
# 22  CDU/CSU             Michael Brand
# 23  CDU/CSU       Dr. Reinhard Brandl
# 24  CDU/CSU     Prof. Dr. Helge Braun             http://twitter.com/HBraun
# 25  CDU/CSU             Silvia Breher
# 26  CDU/CSU           Sebastian Brehm   https://twitter.com/brehm_innbgnord
# 27  CDU/CSU             Heike Brehmer   https://twitter.com/HeikeBrehmerMdB
# 28  CDU/CSU           Ralph Brinkhaus     http://www.twitter.com/rbrinkhaus
# 29  CDU/CSU     Dr. Carsten Brodesser
# 30  CDU/CSU           Gitta Connemann   https://twitter.com/gitta_connemann
# 31  CDU/CSU            Astrid Damerow
# 32  CDU/CSU        Alexander Dobrindt
# 33  CDU/CSU             Michael Donth
# 34  CDU/CSU          Marie-Luise Dött
# 35  CDU/CSU             Hansjörg Durz    https://twitter.com/Hansjoerg_Durz
# 36  CDU/CSU              Thomas Erndl            https://twitter.com/TErndl
# 37  CDU/CSU            Hermann Färber
# 38  CDU/CSU                Uwe Feiler             https://twitter.com/UweFe
# 39  CDU/CSU            Enak Ferlemann
# 40  CDU/CSU           Axel E. Fischer       http://twitter.com/Axel_Fischer
# 41  CDU/CSU     Dr. Maria Flachsbarth
# 42  CDU/CSU             Thorsten Frei     https://twitter.com/thorsten_frei
# 43  CDU/CSU  Dr. Hans-Peter Friedrich    https://twitter.com/HPFriedrichCSU
# 44  CDU/CSU           Michael Frieser    https://twitter.com/MichaelFrieser
# 45  CDU/CSU      Hans-Joachim Fuchtel            http://twitter.com/fuchtel
# 46  CDU/CSU            Ingo Gädechens
# 47  CDU/CSU        Dr. Thomas Gebhart  http://www.twitter.com/thomasgebhart
# 48  CDU/CSU               Alois Gerig
# 49  CDU/CSU          Eberhard Gienger

# %% [markdown]
# ### Save output

# %%
# Save twitter_df

with open('output/twitter_df.pickle', 'wb') as handle:
    pickle.dump(twitter_df, handle, protocol = pickle.HIGHEST_PROTOCOL)
    
# load back in

with open('output/twitter_df.pickle', 'rb') as handle:
    twitter_df = pickle.load(handle)

# %% [markdown]
# ### Merging accounts data into principal MP data

# %%
# Load

with open('output/abg_df.pickle', 'rb') as handle:
    abg_df = pickle.load(handle)

# %%
# Prepare MP names from Twitter df for name-based matching

def name_prep_twitter(name):
    
    interim = re.sub("[\(\[].*?[\)\]]", "", name).strip(' ')
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = unidecode.unidecode(interim).strip(' ')
    interim = re.sub(' +', ' ', interim)
    
    if len(interim.split()) > 2:
        
        if interim.split()[0].endswith(('.', 'med', 'forest')):
            first_name = interim.split()[1]
            
        else:
            first_name = interim.split()[0]   
            
        last_name = interim.split()[-1]
        return (first_name + ' ' + last_name)

        if interim.split()[-1] == 'von':
            first_name = interim.split()[0:-1]     
    
    else:
        return interim

# %%
# Prepare MP names from Twitter df for name-based matching

twitter_df['name_matching'] = twitter_df['name'].apply(name_prep_twitter)

# %%
# Prepare MP names from MP df for name-based matching (helper function)

def name_prep(name):
    
    # Strip titles
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', name) 
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = unidecode.unidecode(interim).strip(' ')
    interim = re.sub(' +', ' ', interim)
    
    if len(interim.split()) > 1:     
        return(interim.split()[0])
    
    else:
        return interim

# %%
# Prepare MP names from MP df for name-based matching

abg_df['name_matching'] = abg_df['first_name'].apply(name_prep) + ' ' + abg_df['last_name'].apply(name_prep)

# %%
# Merge Twitter df and MP df

abg_twitter_df = pd.merge(
    abg_df, 
    twitter_df[['name_matching', 'twitter_ext']], 
    how = 'left', 
    left_on = 'name_matching', 
    right_on = 'name_matching'
)

abg_twitter_df['twitter'] = np.where(
    abg_twitter_df['twitter'] != '', 
    abg_twitter_df['twitter'], 
    np.nan
)

abg_twitter_df['twitter_ext'] = np.where(
    abg_twitter_df['twitter_ext'] != '', 
    abg_twitter_df['twitter_ext'], 
    np.nan
)

# %%
abg_twitter_df[abg_twitter_df['party'] == 'CDU/CSU'].head(30)
# Out:
#           last_name       first_name    party  \
# 0          Abercron  Dr. Michael von  CDU/CSU
# 4            Albani          Stephan  CDU/CSU
# 6         Altenkamp          Norbert  CDU/CSU
# 7          Altmaier            Peter  CDU/CSU
# 8            Amthor          Philipp  CDU/CSU
# 14      Auernhammer            Artur  CDU/CSU
# 15            Aumer            Peter  CDU/CSU
# 19              Bär         Dorothee  CDU/CSU
# 23           Bareiß           Thomas  CDU/CSU
# 27          Barthle          Norbert  CDU/CSU
# 39         Beermann             Maik  CDU/CSU
# 40  Behrens (Börde)          Manfred  CDU/CSU
# 41         Bellmann         Veronika  CDU/CSU
# 42          Benning          Sybille  CDU/CSU
# 43       Berghegger        Dr. André  CDU/CSU
# 45        Bernstein          Melanie  CDU/CSU
# 46        Bernstiel        Christoph  CDU/CSU
# 48            Beyer            Peter  CDU/CSU
# 49          Biadacz             Marc  CDU/CSU
# 50           Bilger          Steffen  CDU/CSU
# 54           Bleser            Peter  CDU/CSU
# 57        Brackmann          Norbert  CDU/CSU
# 58    Brand (Fulda)          Michael  CDU/CSU
# 61           Brandl     Dr. Reinhard  CDU/CSU
# 66            Braun  Prof. Dr. Helge  CDU/CSU
# 69           Breher           Silvia  CDU/CSU
# 70            Brehm        Sebastian  CDU/CSU
# 71          Brehmer            Heike  CDU/CSU
# 73        Brinkhaus            Ralph  CDU/CSU
# 74        Brodesser      Dr. Carsten  CDU/CSU
#
#                                     bundesland  \
# 0       \n\n\n\n\n\n\n  Schleswig-Holstein\n\n
# 4            \n\n\n\n\n\n\n  Niedersachsen\n\n
# 6                   \n\n\n\n\n\n\n  Hessen\n\n
# 7                 \n\n\n\n\n\n\n  Saarland\n\n
# 8   \n\n\n\n\n\n\n  Mecklenburg-Vorpommern\n\n
# 14                  \n\n\n\n\n\n\n  Bayern\n\n
# 15                  \n\n\n\n\n\n\n  Bayern\n\n
# 19                  \n\n\n\n\n\n\n  Bayern\n\n
# 23       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 27       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 39           \n\n\n\n\n\n\n  Niedersachsen\n\n
# 40          \n\n\n\n\n\n\n  Sachsen-Anhalt\n\n
# 41                 \n\n\n\n\n\n\n  Sachsen\n\n
# 42     \n\n\n\n\n\n\n  Nordrhein-Westfalen\n\n
# 43           \n\n\n\n\n\n\n  Niedersachsen\n\n
# 45      \n\n\n\n\n\n\n  Schleswig-Holstein\n\n
# 46          \n\n\n\n\n\n\n  Sachsen-Anhalt\n\n
# 48     \n\n\n\n\n\n\n  Nordrhein-Westfalen\n\n
# 49       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 50       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 69                Wahlkreis 032: Cloppenburg – Vechta
# 70                       Wahlkreis 244: Nürnberg-Nord
# 71                                Wahlkreis 068: Harz
# 73                         Wahlkreis 131: Gütersloh I
# 74                Wahlkreis 099: Oberbergischer Kreis
#
#                                 twitter        name_matching  \
# 0       https://twitter.com/mvabercron/     Michael Abercron
# 4                                   NaN       Stephan Albani
# 6                                   NaN    Norbert Altenkamp
# 7     https://twitter.com/peteraltmaier       Peter Altmaier
# 8                                   NaN       Philipp Amthor
# 14                                  NaN    Artur Auernhammer
# 15                                  NaN          Peter Aumer
# 19                                  NaN         Dorothee Bar
# 23                                  NaN       Thomas Bareiss
# 27                                  NaN      Norbert Barthle
# 39                                  NaN        Maik Beermann
# 40                                  NaN      Manfred Behrens
# 41                                  NaN    Veronika Bellmann
# 42                                  NaN      Sybille Benning
# 43                                  NaN     Andre Berghegger
# 45                                  NaN    Melanie Bernstein
# 46                                  NaN  Christoph Bernstiel
# 48                                  NaN          Peter Beyer
# 49      https://twitter.com/MBiadaczMdB         Marc Biadacz
# 50    https://twitter.com/steffenbilger       Steffen Bilger
# 54                                  NaN         Peter Bleser
# 57                                  NaN    Norbert Brackmann
# 58                                  NaN        Michael Brand
# 61                                  NaN      Reinhard Brandl
# 66                                  NaN          Helge Braun
# 69                                  NaN        Silvia Breher
# 70  https://twitter.com/Brehm_inNBGNord      Sebastian Brehm
# 71                                  NaN        Heike Brehmer
# 73    http://www.twitter.com/rbrinkhaus      Ralph Brinkhaus
# 74                                  NaN    Carsten Brodesser
#
#                             twitter_ext
# 0        https://twitter.com/mvabercron
# 4                                   NaN
# 6                                   NaN
# 7      http://twitter.com/peteraltmaier
# 8                                   NaN
# 14                                  NaN
# 15       https://twitter.com/PeterAumer
# 19          http://twitter.com/DoroBaer
# 23   https://twitter.com/Thomas_Bareiss
# 27                                  NaN
# 39     https://twitter.com/MaikBeermann
# 40    http://twitter.com/Manfredbehrens
# 41                                  NaN
# 42   https://twitter.com/SybilleBenning
# 43                                  NaN
# 45                                  NaN
# 46      https://twitter.com/c_bernstiel
# 48      https://twitter.com/Peter_Beyer
# 49      https://twitter.com/MBiadaczMdB
# 50     http://twitter.com/steffenbilger
# 54                                  NaN
# 57                                  NaN
# 58                                  NaN
# 61                                  NaN
# 66            http://twitter.com/HBraun
# 69                                  NaN
# 70  https://twitter.com/brehm_innbgnord
# 71  https://twitter.com/HeikeBrehmerMdB
# 73    http://www.twitter.com/rbrinkhaus
# 74                                  NaN

# %%
# Impute account name from Bundestag website where necessary and available

abg_twitter_df['twitter'] = np.where(
    abg_twitter_df['twitter_ext'].notnull(), abg_twitter_df['twitter_ext'], abg_twitter_df['twitter'])

abg_twitter_df = abg_twitter_df.drop('twitter_ext', axis = 1)

# %%
abg_twitter_df.head(30)
# Out:
#             last_name       first_name                     party  \
# 0            Abercron  Dr. Michael von                   CDU/CSU
# 1           Achelwilm            Doris                 Die Linke
# 2           Aggelidis        Grigorios                       FDP
# 3             Akbulut            Gökay                 Die Linke
# 4              Albani          Stephan                   CDU/CSU
# 5                 Alt           Renata                       FDP
# 6           Altenkamp          Norbert                   CDU/CSU
# 7            Altmaier            Peter                   CDU/CSU
# 8              Amthor          Philipp                   CDU/CSU
# 9            Amtsberg            Luise     Bündnis 90/Die Grünen
# 10            Andreae          Kerstin  Bündnis 90/Die Grünen  *
# 11              Annen            Niels                       SPD
# 12       Arndt-Brauer           Ingrid                       SPD
# 13  Aschenberg-Dugnus        Christine                       FDP
# 14        Auernhammer            Artur                   CDU/CSU
# 15              Aumer            Peter                   CDU/CSU
# 16               Bach             Bela                       SPD
# 17              Badum             Lisa     Bündnis 90/Die Grünen
# 18           Baehrens            Heike                       SPD
# 19                Bär         Dorothee                   CDU/CSU
# 20           Baerbock         Annalena     Bündnis 90/Die Grünen
# 21               Bahr           Ulrike                       SPD
# 22           Baradari          Nezahat                       SPD
# 23             Bareiß           Thomas                   CDU/CSU
# 24             Barley     Dr. Katarina                    SPD  *
# 25            Barnett            Doris                       SPD
# 26         Barrientos           Simone                 Die Linke
# 27            Barthle          Norbert                   CDU/CSU
# 28             Bartke     Dr. Matthias                       SPD
# 29             Bartol            Sören                       SPD
#
#                                     bundesland  \
# 0       \n\n\n\n\n\n\n  Schleswig-Holstein\n\n
# 1                                       Bremen
# 2            \n\n\n\n\n\n\n  Niedersachsen\n\n
# 3        \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 4            \n\n\n\n\n\n\n  Niedersachsen\n\n
# 5        \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 6                   \n\n\n\n\n\n\n  Hessen\n\n
# 7                 \n\n\n\n\n\n\n  Saarland\n\n
# 8   \n\n\n\n\n\n\n  Mecklenburg-Vorpommern\n\n
# 9       \n\n\n\n\n\n\n  Schleswig-Holstein\n\n
# 10       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 11                 \n\n\n\n\n\n\n  Hamburg\n\n
# 12     \n\n\n\n\n\n\n  Nordrhein-Westfalen\n\n
# 13      \n\n\n\n\n\n\n  Schleswig-Holstein\n\n
# 14                  \n\n\n\n\n\n\n  Bayern\n\n
# 15                  \n\n\n\n\n\n\n  Bayern\n\n
# 16                  \n\n\n\n\n\n\n  Bayern\n\n
# 17                  \n\n\n\n\n\n\n  Bayern\n\n
# 18       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 19                  \n\n\n\n\n\n\n  Bayern\n\n
# 20             \n\n\n\n\n\n\n  Brandenburg\n\n
# 21                  \n\n\n\n\n\n\n  Bayern\n\n
# 22     \n\n\n\n\n\n\n  Nordrhein-Westfalen\n\n
# 23       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 24         \n\n\n\n\n\n\n  Rheinland-Pfalz\n\n
# 25         \n\n\n\n\n\n\n  Rheinland-Pfalz\n\n
# 26                  \n\n\n\n\n\n\n  Bayern\n\n
# 27       \n\n\n\n\n\n\n  Baden-Württemberg\n\n
# 28                 \n\n\n\n\n\n\n  Hamburg\n\n
# 6                                         NaN            Norbert Altenkamp
# 7            http://twitter.com/peteraltmaier               Peter Altmaier
# 8                                         NaN               Philipp Amthor
# 9                                         NaN               Luise Amtsberg
# 10                                        NaN              Kerstin Andreae
# 11              http://twitter.com/NielsAnnen                  Niels Annen
# 12                                        NaN          Ingrid Arndt-Brauer
# 13          https://twitter.com/cad59?lang=de  Christine Aschenberg-Dugnus
# 14                                        NaN            Artur Auernhammer
# 15             https://twitter.com/PeterAumer                  Peter Aumer
# 16              https://twitter.com/bela_bach                    Bela Bach
# 17        https://twitter.com/badulrichmartha                   Lisa Badum
# 18                                        NaN               Heike Baehrens
# 19                http://twitter.com/DoroBaer                 Dorothee Bar
# 20              https://twitter.com/ABaerbock            Annalena Baerbock
# 21        https://twitter.com/MdB_Ulrike_Bahr                  Ulrike Bahr
# 22                                        NaN             Nezahat Baradari
# 23         https://twitter.com/Thomas_Bareiss               Thomas Bareiss
# 24                                        NaN              Katarina Barley
# 25                                        NaN                Doris Barnett
# 26           https://twitter.com/SBarrientosK            Simone Barrientos
# 27                                        NaN              Norbert Barthle
# 28        https://twitter.com/matthiasbartke               Matthias Bartke
# 29            http://twitter.com/soerenbartol                 Soren Bartol

# %% [markdown]
# ### Converting Twitter URL to Twitter username

# %%
# URL to username (helper function)

def get_username(url):
    
    if url.startswith('http'):
        return(url.split('/')[3].split('?')[0])
    
    else:
        return(url.split('?')[0])

# %%
# URL to username

mask1 = abg_twitter_df['twitter'].notnull()
abg_twitter_df['twitter'] = abg_twitter_df['twitter'][mask1].apply(get_username)

# %%
abg_twitter_df.head(50)
# Out:
#             last_name       first_name                     party  \
# 0            Abercron  Dr. Michael von                   CDU/CSU
# 1           Achelwilm            Doris                 Die Linke
# 2           Aggelidis        Grigorios                       FDP
# 3             Akbulut            Gökay                 Die Linke
# 4              Albani          Stephan                   CDU/CSU
# 5                 Alt           Renata                       FDP
# 6           Altenkamp          Norbert                   CDU/CSU
# 7            Altmaier            Peter                   CDU/CSU
# 8              Amthor          Philipp                   CDU/CSU
# 9            Amtsberg            Luise     Bündnis 90/Die Grünen
# 10            Andreae          Kerstin  Bündnis 90/Die Grünen  *
# 11              Annen            Niels                       SPD
# 12       Arndt-Brauer           Ingrid                       SPD
# 13  Aschenberg-Dugnus        Christine                       FDP
# 14        Auernhammer            Artur                   CDU/CSU
# 15              Aumer            Peter                   CDU/CSU
# 16               Bach             Bela                       SPD
# 17              Badum             Lisa     Bündnis 90/Die Grünen
# 18           Baehrens            Heike                       SPD
# 19                Bär         Dorothee                   CDU/CSU
# 20           Baerbock         Annalena     Bündnis 90/Die Grünen
# 21               Bahr           Ulrike                       SPD
# 22           Baradari          Nezahat                       SPD
# 23             Bareiß           Thomas                   CDU/CSU
# 24             Barley     Dr. Katarina                    SPD  *
# 25            Barnett            Doris                       SPD
# 26         Barrientos           Simone                 Die Linke
# 27            Barthle          Norbert                   CDU/CSU
# 28             Bartke     Dr. Matthias                       SPD
# 29             Bartol            Sören                       SPD
# 43           Niedersachsen                                     Osnabrück-Land
# 44       Baden-Württemberg                                    Karlsruhe-Stadt
# 45                     NaN                                                NaN
# 46          Sachsen-Anhalt                                              Halle
# 47      Schleswig-Holstein                                  Plön – Neumünster
# 48     Nordrhein-Westfalen                                        Mettmann II
# 49       Baden-Württemberg                                          Böblingen
#
#    wahlkreis_nr          twitter                name_matching
# 0             7       mvabercron             Michael Abercron
# 1           NaN  doris_achelwilm              Doris Achelwilm
# 2            43    aggelidis_fdp          Grigorios Aggelidis
# 3           275     akbulutgokay                Gokay Akbulut
# 4            27              NaN               Stephan Albani
# 5           NaN              NaN                   Renata Alt
# 6           181              NaN            Norbert Altenkamp
# 7           297    peteraltmaier               Peter Altmaier
# 8            16              NaN               Philipp Amthor
# 9           NaN              NaN               Luise Amtsberg
# 10          281              NaN              Kerstin Andreae
# 11           20       NielsAnnen                  Niels Annen
# 12          124              NaN          Ingrid Arndt-Brauer
# 13            4            cad59  Christine Aschenberg-Dugnus
# 14          241              NaN            Artur Auernhammer
# 15          233       PeterAumer                  Peter Aumer
# 16          NaN        bela_bach                    Bela Bach
# 17          236  badulrichmartha                   Lisa Badum
# 18          NaN              NaN               Heike Baehrens
# 19          248         DoroBaer                 Dorothee Bar
# 20           61        ABaerbock            Annalena Baerbock
# 21          252  MdB_Ulrike_Bahr                  Ulrike Bahr
# 22          149              NaN             Nezahat Baradari
# 23          295   Thomas_Bareiss               Thomas Bareiss
# 24          NaN              NaN              Katarina Barley
# 25          207              NaN                Doris Barnett
# 26          251     SBarrientosK            Simone Barrientos
# 27          269              NaN              Norbert Barthle
# 28           19  matthiasbartke               Matthias Bartke
# 29          171     soerenbartol                 Soren Bartol
# 30          NaN   DietmarBartsch              Dietmar Bartsch
# 31          115       baerbelbas                   Barbel Bas
# 32          228  nicole_ae_bauer                 Nicole Bauer
# 33           19  berndbaumannafd                Bernd Baumann
# 34          218   MargareteBause              Margarete Bause
# 35          278        derdanyal                 Danyal Bayaz
# 36           83    LieblingXhain                 Canan Bayram
# 37           31        jensbeeck                   Jens Beeck
# 38          182              NaN                  Nicola Beer
# 39           40     MaikBeermann                Maik Beermann
# 40           67   Manfredbehrens              Manfred Behrens
# 41          NaN              NaN            Veronika Bellmann
# 42          129   SybilleBenning              Sybille Benning
# 43           38              NaN             Andre Berghegger
# 44          271  MarcBernhardAfD                Marc Bernhard
# 45          NaN              NaN            Melanie Bernstein
# 46           72      c_bernstiel          Christoph Bernstiel
# 47            6         lgbeutin                Lorenz Beutin
# 48          105      Peter_Beyer                  Peter Beyer
# 49          260      MBiadaczMdB                 Marc Biadacz

# %%
len(abg_twitter_df) - abg_twitter_df['twitter'].isnull().sum()
# Out:
# 472

# %% [markdown]
# ### Saving

# %%
# Save

with open('output/abg_twitter_df.pickle', 'wb') as handle:
    pickle.dump(abg_twitter_df, handle, protocol = pickle.HIGHEST_PROTOCOL)
abg_twitter_df.to_csv('output/abg_twitter_df.csv', index = False, encoding = 'utf-8-sig')
