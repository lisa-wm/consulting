# %% [markdown]
# # Scraping Twitter accounts from party websites

# %% [markdown]
# Note: In case of the AfD party, Twitter accounts are not available on the official party website and must thus be gathered manually.

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import pickle
import numpy as np
import unidecode
import os

# %%
# set up working directory
os.path.abspath(os.getcwd()) # initial working directory (should be equal to source file directory if using Jupyter Notebook)
os.chdir('../../data/web_scraping') # change to directory where all data files are stored
# check working directory
os.path.abspath(os.getcwd())
# Out:
# 'C:\\Users\\Simon\\OneDrive\\Uni\\LMU\\SS 2020\\Statistisches Consulting\\Bundestag-MP-Analyse\\data\\web_scraping'

# %% [markdown]
# ### Setup

# %%
# access party websites, convert into soups 
# fdp = "https://www.fdpbt.de/fraktion/abgeordnete"
# source_fdp = requests.get(fdp).text
# soup_fdp = BeautifulSoup(source_fdp, 'html.parser')

cdu = "https://www.cducsu.de/hier-stellt-die-cducsu-bundestagsfraktion-ihre-abgeordneten-vor"
source_cdu = requests.get(cdu).text
soup_cdu = BeautifulSoup(source_cdu, 'html.parser')

spd = "https://www.spdfraktion.de/abgeordnete/alle?wp=19&view=list&old=19"
source_spd = requests.get(spd).text
soup_spd = BeautifulSoup(source_spd, 'html.parser')

gruene = "https://www.gruene-bundestag.de/abgeordnete"
source_gruene = requests.get(gruene).text
soup_gruene = BeautifulSoup(source_gruene, 'html.parser')

# for Die Linke, one needs to extract Twitter accounts from each individual MP website
linke_base = "https://www.linksfraktion.de/fraktion/abgeordnete/"
letters = [['a', 'e'], ['f', 'j'], ['k', 'o'], ['p', 't'], ['u', 'z']] # website contains bins of MPs, according to last name
linke_name_bins = []

for letter in letters:
    extension = f'{letter[0]}-bis-{letter[1]}/' 
    linke_name_bins.append(linke_base + extension)

# %%
# for each party, find appropriate parent node in soup

# all_abg_fdp = soup_fdp.find(class_ = 'person-list').find_all(class_ = 'person-item-wrapper')
all_abg_cdu = soup_cdu.find_all(class_ = 'teaser delegates')
all_abg_spd = soup_spd.find_all(class_ = 'views-row')

extensions_gruene = soup_gruene.find_all('a', class_="abgeordneteTeaser__wrapper")
urlbase_gruene = 'https://www.gruene-bundestag.de'
all_abg_gruene = []
for a in extensions_gruene:
    extension = a['href']
    link = urlbase_gruene + str(extension)
    all_abg_gruene.append(link)
    
all_abg_linke = []
for name_bin in linke_name_bins:
    source = requests.get(name_bin).text
    soup = BeautifulSoup(source, 'html.parser')
    for abg in soup.find_all('div', attrs = {'class': 'col-xs-12 col-sm-12 col-md-6 col-lg-6'}):
        extension = abg.find('h2').find('a')['href'].lstrip('/fraktion/abgeordnete/')
        all_abg_linke.append(linke_base + extension)

# %% [markdown]
# ### Scraping

# %%
# set up empty list
twitter_list = []

# # FDP
# for abg in all_abg_fdp:
#     name_field = abg.find(class_ = 'person-name')
#     funktion = name_field.find('span').text.strip()
#     name = name_field.text.strip('\n').strip().rstrip(funktion).strip('\n').strip()
#     twitter = abg.find('a', attrs = {'class': 'tw'}, href = True)
#     twitter_list.append(
#         {
#         'Partei': "FDP",
#         'Name': name,
#         'Twitter': twitter['href'] if twitter is not None else ""
#             }
#         )

# CDU/CSU
for abg in all_abg_cdu:
    twitter = abg.find(class_ = 'twitter')
    twitter_list.append(
        {
        'Partei': "CDU/CSU",
        'Name': abg.find('h2').find('span').text.strip(' '),
        'Twitter': twitter.find('a', href = True)['href'] if twitter is not None else ""
            }
        )

# SPD
for abg in all_abg_spd:
    twitter = abg.find(class_ = 'ico_twitter')
    twitter_list.append(
        {
        'Partei': "SPD",
        'Name': abg.find('h3').find('a').get_text().strip(' '),
        'Twitter': twitter['href'] if twitter is not None else ""
            }
        )

# Bündnis 90/Die Grünen
for abg in all_abg_gruene:
    abg_source = requests.get(abg).text
    abg_soup = BeautifulSoup(abg_source, 'html.parser')
    hrefss = []
    twitter = ""
    for x in abg_soup.find_all(class_="weitereInfoTeaser"):
        for y in x.find_all('a', href = True):
            z = y['href']
            hrefss.append(z)
            for i in hrefss:
                if "twitter" not in i:
                    continue 
                else:
                    twitter = i
                    
    twitter_list.append(           
        {
        'Partei': "Bündnis 90/Die Grünen",
        'Name': abg_soup.find('h1').text,
        'Twitter': twitter
            }
        )

# Die Linke
for abg in all_abg_linke:
    abg_source = requests.get(abg).text
    abg_soup = BeautifulSoup(abg_source, 'html.parser')
    twitter = abg_soup.find('a', text = re.compile('Twitter-Profil'))
    twitter_list.append(
        {
        'Partei': "Die Linke",
        'Name': abg_soup.find('h1').text.strip(' '),
        'Twitter': twitter['href'] if twitter is not None else ""
            }
        )

# %% [markdown]
# ### Adding AfD, saving output

# %%
# adding manually scraped Twitter accounts from AfD party members
afd_df = pd.read_csv('AFD.csv', encoding = "ISO-8859-1", delimiter = ';')
afd_df.columns = ['Name', 'Partei', 'Twitter']
columns_titles = ['Partei', 'Name', 'Twitter']
afd_df=afd_df.reindex(columns=columns_titles)

# %%
# convert into dataframe
twitter_df = pd.DataFrame(twitter_list)
# append AfD Twitter accounts
twitter_df = twitter_df.append(afd_df)

# %%
# # saving twitter_df
# with open('twitter_df.pickle', 'wb') as handle:
#     pickle.dump(twitter_df, handle, protocol=pickle.HIGHEST_PROTOCOL)
# # load back in
# with open('twitter_df.pickle', 'rb') as handle:
#     twitter_df = pickle.load(handle)

# %% [markdown]
# ### Merging Twitter accounts df into the principal MP df

# %%
# load in data
with open('abg_df.pickle', 'rb') as handle:
    df = pickle.load(handle)

# %%
# prepare MP names from Twitter df for name-based matching (helper function)
def name_prep_twitter(name):
    interim = re.sub("[\(\[].*?[\)\]]", "", name).strip(' ')
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = unidecode.unidecode(interim).strip(' ')
    interim = re.sub(' +', ' ', interim)
    if len(interim.split()) > 2:
        if interim.split()[0].endswith(('.', 'med', 'forest')):
            first_name = interim.split()[1]
        else:
            first_name = interim.split()[0]   
        last_name = interim.split()[-1]
        return (first_name + ' ' + last_name)
    else:
        return interim

# %%
# test
name_prep_twitter('Prof. Dr. med. Axel Gehrke')
# Out:
# 'Axel Gehrke'

# %%
# prepare MP names from Twitter df for name-based matching
twitter_df['Name_matching'] = twitter_df['Name'].apply(name_prep_twitter)

# %%
# prepare MP names from MP df for name-based matching (helper function)
def name_prep(name):
    interim = re.sub("[\(\[].*?[\)\]]", "", ' '.join(name.split(',')[::-1])).strip(' ') # placing first name before last name
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim) # stripping titles
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = re.sub(r'(^\w{1,6}\. ?)', r'', interim)
    interim = unidecode.unidecode(interim).strip(' ')
    interim = re.sub(' +', ' ', interim)
    if len(interim.split()) > 2:
        if interim.split()[0].endswith(('.', 'med', 'forest')):
            first_name = interim.split()[1]
        else:
            first_name = interim.split()[0]   
        last_name = interim.split()[-1]
        return (first_name + ' ' + last_name)
    else:
        return interim

# %%
# prepare MP names from MP df for name-based matching
df['Name_matching'] = df['Name'].apply(name_prep)

# %%
# merging Twitter df and MP df
df = pd.merge(df, twitter_df, how = 'left', left_on = 'Name_matching', right_on = 'Name_matching', suffixes = ('', '_right'))

# %%
# in case non-matches occur: identify them
# non_matches = []
# for i in range(len(df)):
#     if (df['Name_matching'][i] != df['Name_matching'][i]):
#         non_matches.append(i)

# print(non_matches)

# %%
# filling up Twitter-column with values from Soziale Medien-dictionary (helper function)
def get_twitter_from_dict(x):
    if 'Twitter' in x:
        return x['Twitter']

# %%
# filling up Twitter-column with values from Soziale Medien-dictionary
df['Twitter_dict'] = df['Soziale Medien'].apply(get_twitter_from_dict)
df['Twitter'] = np.where(df['Twitter_dict'].notnull(), df['Twitter_dict'], df['Twitter'])

# dropping columns used for merging only
columns_to_keep = ['Name', 'Partei', 'Wahlart', 'Bundesland', 'Wahlkreis', 'Wahlkreis-Nr.', 'Ausschuesse', 'Soziale Medien', 'Biografie', 'Twitter']
df.drop(df.columns.difference(columns_to_keep), 1, inplace=True)

# %% [markdown]
# ### Converting Twitter URL to Twitter username

# %%
# URL to username (helper function)
def get_username(url):
    if url.startswith('http'):
        return(url.split('/')[3].split('?')[0])
    else:
        return(url.split('?')[0])

# %%
mask1 = df['Twitter'].notnull()

# %%
# URL to username
df['Twitter'] = df['Twitter'][mask1].apply(get_username)

# %%
df.head(50)
# Out:
#                             Name                    Partei  \
# 0      Abercron, Dr. Michael von                   CDU/CSU
# 1               Achelwilm, Doris                 Die Linke
# 2           Aggelidis, Grigorios                       FDP
# 3                 Akbulut, Gökay                 Die Linke
# 4                Albani, Stephan                   CDU/CSU
# 5                    Alt, Renata                       FDP
# 6             Altenkamp, Norbert                   CDU/CSU
# 7                Altmaier, Peter                   CDU/CSU
# 8                Amthor, Philipp                   CDU/CSU
# 9                Amtsberg, Luise     Bündnis 90/Die Grünen
# 10              Andreae, Kerstin  Bündnis 90/Die Grünen  *
# 11                  Annen, Niels                       SPD
# 12          Arndt-Brauer, Ingrid                       SPD
# 13  Aschenberg-Dugnus, Christine                       FDP
# 14            Auernhammer, Artur                   CDU/CSU
# 15                  Aumer, Peter                   CDU/CSU
# 16                    Bach, Bela                       SPD
# 17                   Badum, Lisa     Bündnis 90/Die Grünen
# 18               Baehrens, Heike                       SPD
# 19                 Bär, Dorothee                   CDU/CSU
# 20            Baerbock, Annalena     Bündnis 90/Die Grünen
# 21                  Bahr, Ulrike                       SPD
# 22             Baradari, Nezahat                       SPD
# 23                Bareiß, Thomas                   CDU/CSU
# 24          Barley, Dr. Katarina                    SPD  *
# 25                Barnett, Doris                       SPD
# 26            Barrientos, Simone                 Die Linke
# 27              Barthle, Norbert                   CDU/CSU
# 28          Bartke, Dr. Matthias                       SPD
# 29                 Bartol, Sören                       SPD
# 30          Bartsch, Dr. Dietmar                 Die Linke
# 31                   Bas, Bärbel                       SPD
# 32                 Bauer, Nicole                       FDP
# 33            Baumann, Dr. Bernd                       AfD
# 34              Bause, Margarete     Bündnis 90/Die Grünen
# 35             Bayaz, Dr. Danyal     Bündnis 90/Die Grünen
# 36                 Bayram, Canan     Bündnis 90/Die Grünen
# 37                   Beeck, Jens                       FDP
# 38                  Beer, Nicola                    FDP  *
# 39                Beermann, Maik                   CDU/CSU
# 40      Behrens (Börde), Manfred                   CDU/CSU
# 41            Bellmann, Veronika                   CDU/CSU
# 42              Benning, Sybille                   CDU/CSU
# 43         Berghegger, Dr. André                   CDU/CSU
# 44                Bernhard, Marc                       AfD
# 45            Bernstein, Melanie                   CDU/CSU
# 46          Bernstiel, Christoph                   CDU/CSU
# 47          Beutin, Lorenz Gösta                 Die Linke
# 48                  Beyer, Peter                   CDU/CSU
# 49                 Biadacz, Marc                   CDU/CSU
#
#                      Wahlart              Bundesland  \
# 0             Direkt gewählt      Schleswig-Holstein
# 1   Gewählt über Landesliste                  Bremen
# 2   Gewählt über Landesliste           Niedersachsen
# 3   Gewählt über Landesliste       Baden-Württemberg
# 4   Gewählt über Landesliste           Niedersachsen
# 5   Gewählt über Landesliste       Baden-Württemberg
# 6             Direkt gewählt                  Hessen
# 7             Direkt gewählt                Saarland
# 8             Direkt gewählt  Mecklenburg-Vorpommern
# 9   Gewählt über Landesliste      Schleswig-Holstein
# 10  Gewählt über Landesliste       Baden-Württemberg
# 11            Direkt gewählt                 Hamburg
# 12  Gewählt über Landesliste     Nordrhein-Westfalen
# 13  Gewählt über Landesliste      Schleswig-Holstein
# 14            Direkt gewählt                  Bayern
# 15            Direkt gewählt                  Bayern
# 16  Gewählt über Landesliste                  Bayern
# 17  Gewählt über Landesliste                  Bayern
# 18  Gewählt über Landesliste       Baden-Württemberg
# 19            Direkt gewählt                  Bayern
# 20  Gewählt über Landesliste             Brandenburg
# 21  Gewählt über Landesliste                  Bayern
# 22  Gewählt über Landesliste     Nordrhein-Westfalen
# 23            Direkt gewählt       Baden-Württemberg
# 24  Gewählt über Landesliste         Rheinland-Pfalz
# 25  Gewählt über Landesliste         Rheinland-Pfalz
# 26  Gewählt über Landesliste                  Bayern
# 27            Direkt gewählt       Baden-Württemberg
# 28            Direkt gewählt                 Hamburg
# 29            Direkt gewählt                  Hessen
# 30  Gewählt über Landesliste  Mecklenburg-Vorpommern
# 31            Direkt gewählt     Nordrhein-Westfalen
# 32  Gewählt über Landesliste                  Bayern
# 33  Gewählt über Landesliste                 Hamburg
# 34  Gewählt über Landesliste                  Bayern
# 35  Gewählt über Landesliste       Baden-Württemberg
# 36            Direkt gewählt                  Berlin
# 37  Gewählt über Landesliste           Niedersachsen
# 38  Gewählt über Landesliste                  Hessen
# 39            Direkt gewählt           Niedersachsen
# 40            Direkt gewählt          Sachsen-Anhalt
# 41            Direkt gewählt                 Sachsen
# 42            Direkt gewählt     Nordrhein-Westfalen
# 43            Direkt gewählt           Niedersachsen
# 44  Gewählt über Landesliste       Baden-Württemberg
# 45            Direkt gewählt      Schleswig-Holstein
# 46            Direkt gewählt          Sachsen-Anhalt
# 47  Gewählt über Landesliste      Schleswig-Holstein
# 48            Direkt gewählt     Nordrhein-Westfalen
# 49            Direkt gewählt       Baden-Württemberg
#
#                                             Wahlkreis  \
# 0                            Wahlkreis 007: Pinneberg
# 1                                                n.a.
# 2                      Wahlkreis 043: Hannover-Land I
# 3                             Wahlkreis 275: Mannheim
# 4                Wahlkreis 027: Oldenburg – Ammerland
# 5                            Wahlkreis 262: Nürtingen
# 6                          Wahlkreis 181: Main-Taunus
# 7                            Wahlkreis 297: Saarlouis
# 8   Wahlkreis 016: Mecklenburgische Seenplatte I –...
# 9                                 Wahlkreis 005: Kiel
# 10                            Wahlkreis 281: Freiburg
# 11                  Wahlkreis 020: Hamburg-Eimsbüttel
# 12              Wahlkreis 124: Steinfurt I – Borken I
# 13               Wahlkreis 004: Rendsburg-Eckernförde
# 14                             Wahlkreis 241: Ansbach
# 15                          Wahlkreis 233: Regensburg
# 16                        Wahlkreis 221: München-Land
# 17                             Wahlkreis 236: Bamberg
# 18                           Wahlkreis 263: Göppingen
# 19                       Wahlkreis 248: Bad Kissingen
# 20  Wahlkreis 061: Potsdam – Potsdam-Mittelmark II...
# 21                      Wahlkreis 252: Augsburg-Stadt
# 22           Wahlkreis 149: Olpe – Märkischer Kreis I
# 23            Wahlkreis 295: Zollernalb – Sigmaringen
# 24                               Wahlkreis 203: Trier
# 25            Wahlkreis 207: Ludwigshafen/Frankenthal
# 26                            Wahlkreis 251: Würzburg
# 27         Wahlkreis 269: Backnang – Schwäbisch Gmünd
# 28                      Wahlkreis 019: Hamburg-Altona
# 29                             Wahlkreis 171: Marburg
# 30      Wahlkreis 014: Rostock – Landkreis Rostock II
# 31                          Wahlkreis 115: Duisburg I
# 32                            Wahlkreis 228: Landshut
# 33                      Wahlkreis 019: Hamburg-Altona
# 34                         Wahlkreis 218: München-Ost
# 35             Wahlkreis 278: Bruchsal – Schwetzingen
# 36  Wahlkreis 083: Berlin-Friedrichshain-Kreuzberg...
# 37                           Wahlkreis 031: Mittelems
# 38                 Wahlkreis 182: Frankfurt am Main I
# 39            Wahlkreis 040: Nienburg II – Schaumburg
# 40             Wahlkreis 067: Börde – Jerichower Land
# 41                       Wahlkreis 161: Mittelsachsen
# 42                             Wahlkreis 129: Münster
# 43                      Wahlkreis 038: Osnabrück-Land
# 44                     Wahlkreis 271: Karlsruhe-Stadt
# 45                   Wahlkreis 006: Plön – Neumünster
# 46                               Wahlkreis 072: Halle
# 47                   Wahlkreis 006: Plön – Neumünster
# 48                         Wahlkreis 105: Mettmann II
# 49                           Wahlkreis 260: Böblingen
#
#                                           Ausschuesse  \
# 0   {'Ordentliches Mitglied': ['Ausschuss für Ernä...
# 1   {'Ordentliches Mitglied': ['Ausschuss für Fami...
# 2   {'Ordentliches Mitglied': ['Kuratorium der Bun...
# 3   {'Ordentliches Mitglied': ['Schriftführer/in',...
# 4   {'Ordentliches Mitglied': ['Ausschuss für Bild...
# 5   {'Obfrau': ['Unterausschuss für Zivile Krisenp...
# 6   {'Ordentliches Mitglied': ['Schriftführer/in',...
# 7   {'Bundesminister für Wirtschaft und Energie': []}
# 8   {'Ordentliches Mitglied': ['Ausschuss für Inne...
# 9   {'Ordentliches Mitglied': ['Ausschuss für Inne...
# 10  {'Funktionen in Unternehmen': [], 'Funktionen ...
# 11          {'Staatsminister im Auswärtigen Amt': []}
# 12  {'Ordentliches Mitglied': ['Gremium nach § 23c...
# 13  {'Ordentliches Mitglied': ['Ausschuss für Gesu...
# 14  {'Ordentliches Mitglied': ['Schriftführer/in',...
# 15  {'Ordentliches Mitglied': ['Ausschuss für Arbe...
# 16  {'Ordentliches Mitglied': ['Petitionsausschuss...
# 17  {'Ordentliches Mitglied': ['Ausschuss für Umwe...
# 18  {'Vorsitzende': ['Unterausschuss Globale Gesun...
# 19             {'Staatsministerin für Digitales': []}
# 20  {'Stellvertretendes Mitglied': ['Ausschuss für...
# 21  {'Ordentliches Mitglied': ['Unterausschuss Bür...
# 22  {'Ordentliches Mitglied': ['Ausschuss für die ...
# 23  {'Parlamentarischer Staatssekretär für Wirtsch...
# 24  {'Funktionen in Unternehmen': [], 'Funktionen ...
# 25  {'Vorsitzende': ['Unterausschuss zu Fragen der...
# 26  {'Obfrau': ['Ausschuss für Kultur und Medien']...
# 27  {'Parlamentarischer Staatssekretär für wirtsch...
# 28  {'Vorsitzender': ['Ausschuss für Arbeit und So...
# 29  {'Ordentliches Mitglied': ['Vermittlungsaussch...
# 30  {'Ordentliches Mitglied': ['Gemeinsamer Aussch...
# 31  {'Ordentliches Mitglied': ['Gemeinsamer Aussch...
# 32  {'Ordentliches Mitglied': ['Ausschuss für Ernä...
# 33  {'Ordentliches Mitglied': ['Der Ältestenrat', ...
# 34  {'Obfrau': ['Ausschuss für Menschenrechte und ...
# 35  {'Ordentliches Mitglied': ['Finanzausschuss', ...
# 36  {'Ordentliches Mitglied': ['Ausschuss für Rech...
# 37  {'Ordentliches Mitglied': ['Ausschuss für Arbe...
# 38  {'Berufliche Tätigkeit vor der Mitgliedschaft ...
# 39  {'Obmann': ['Ausschuss Digitale Agenda'], 'Ord...
# 40  {'Ordentliches Mitglied': ['Ausschuss für Verk...
# 41  {'Ordentliches Mitglied': ['Ausschuss für Verk...
# 42  {'Stellv. Vorsitzende': ['Ausschuss für Bildun...
# 43  {'Obmann': ['Haushaltsausschuss', 'Rechnungspr...
# 44  {'Ordentliches Mitglied': ['Ausschuss für Umwe...
# 45  {'Obfrau': ['Ausschuss für Kultur und Medien']...
# 46  {'Ordentliches Mitglied': ['Schriftführer/in',...
# 47  {'Ordentliches Mitglied': ['Ausschuss für Wirt...
# 48  {'Ordentliches Mitglied': ['Unterausschuss Ver...
# 49  {'Ordentliches Mitglied': ['Ausschuss für Arbe...
#
#                                        Soziale Medien  \
# 0   {'von-abercron.de/': 'http://www.von-abercron....
# 1   {'doris-achelwilm.de': 'http://www.doris-achel...
# 2   {'grigorios-aggelidis.de': 'http://www.grigori...
# 3   {'goekay-akbulut.de': 'https://goekay-akbulut....
# 4   {'stephan-albani.de': 'http://www.stephan-alba...
# 5   {'renata-alt.de': 'http://www.renata-alt.de', ...
# 6   {'norbert-altenkamp.de': 'http://www.norbert-a...
# 7   {'peteraltmaier.de': 'http://www.peteraltmaier...
# 8   {'philipp-amthor.de': 'http://www.philipp-amth...
# 9   {'luise-amtsberg.de': 'http://www.luise-amtsbe...
# 10                                                 {}
# 11      {'nielsannen.de': 'http://www.nielsannen.de'}
# 12  {'arndt-brauer.de': 'http://www.arndt-brauer.de'}
# 13  {'caschenbergdugnus.abgeordnete.fdpbt.de': 'ht...
# 14  {'Facebook': 'https://www.facebook.com/Auernha...
# 15  {'peter-aumer.de': 'http://www.peter-aumer.de/...
# 16  {'Facebook': 'https://www.facebook.com/BelaBac...
# 17  {'lisa-badum.de': 'http://www.lisa-badum.de/',...
# 18  {'heike-baehrens.de': 'http://www.heike-baehre...
# 19  {'dorothee-baer.de': 'http://www.dorothee-baer...
# 20                                                 {}
# 21                                                 {}
# 22  {'www.nezahat-baradari.de': 'https://www.nezah...
# 23  {'thomas-bareiss.de': 'http://www.thomas-barei...
# 24                                                 {}
# 25  {'doris-barnett.de': 'http://www.Doris-Barnett...
# 26  {'simone-barrientos.de': 'http://simone-barrie...
# 27            {'barthle.de': 'http://www.barthle.de'}
# 28                                                 {}
# 29             {'bartol.de': 'http://www.bartol.de/'}
# 30  {'dietmar-bartsch.de': 'http://www.dietmar-bar...
# 31     {'baerbelbas.de': 'http://www.baerbelbas.de/'}
# 32  {'fdp-nicole-bauer.de': 'http://fdp-nicole-bau...
# 33  {'Facebook': 'https://www.facebook.com/Dr.Bern...
# 34  {'margarete-bause.de': 'http://www.margarete-b...
# 35  {'danyal.eu': 'https://www.danyal.eu/', 'Faceb...
# 36  {'bayram-gruene.de': 'http://bayram-gruene.de/...
# 37  {'jensbeeck.de': 'http://www.jensbeeck.de/', '...
# 38                                                 {}
# 39  {'maik-beermann.de': 'http://www.maik-beermann...
# 40                                                 {}
# 41  {'veronika-bellmann.de': 'http://www.veronika-...
# 42                                                 {}
# 43  {'andre-berghegger.de': 'http://www.andre-berg...
# 44  {'MarcBernhard.de': 'http://www.marcbernhard.d...
# 45  {'melanie-bernstein.de/': 'http://www.melanie-...
# 46  {'christoph-bernstiel.de': 'http://www.christo...
# 47  {'lorenz-goesta-beutin.de': 'https://www.loren...
# 48  {'Facebook': 'http://www.facebook.com/PeterBey...
# 49  {'marc-biadacz.de': 'https://www.marc-biadacz....
#
#                                             Biografie          Twitter
# 0           Geboren am 17. November 1952 in Ehlers...       mvabercron
# 1           Geboren am 30. November 1976 in Thuine...   DorisAchelwilm
# 2           Geboren am 19. August 1965 in Hannover...    aggelidis_fdp
# 3   Geboren 1982 in Pinarbasi/ Türkei; ledig.Juni ...     akbulutgokay
# 4   Geboren am 3. Juni 1968 in Göttingen; verheira...
# 5           Geboren am 27. August 1965 in Skalica;...    RenataAlt_MdB
# 6           Geboren am 27. Juli 1972 in Marl/Westf...
# 7   Geboren am 18. Juni 1958 in Ensdorf, Saar; kat...    peteraltmaier
# 8           Geboren am 10. November 1992 in Uecker...
# 9   Geboren am 17. Oktober 1984 in Greifswald.2004...
# 10  Geboren am 21. Oktober 1968 in Schramberg; eva...              NaN
# 11  Geboren am 6. April 1973 in Hamburg-Eimsbüttel...       NielsAnnen
# 12  Geboren am 20. März 1961 in Marburg; verheirat...
# 13          Geboren am 22. September 1959 in Eppst...            cad59
# 14  Geboren am 9. März 1963 in Oberhochstatt, Stad...
# 15  Geboren am 17. April 1976 in Regensburg; römis...       PeterAumer
# 16          Geboren am 30. September 1990 in Magde...        bela_bach
# 17          Geboren am 2. Oktober 1983;\n        \...  badulrichmartha
# 18  Geboren am 21. September 1955 in Bevern; evang...
# 19  Geboren am 19. April 1978 in Bamberg; römisch-...         DoroBaer
# 20  Geboren am 15. Dezember 1980 in Hannover; evan...        ABaerbock
# 21  Geboren am 25. April 1964 in Nördlingen; römis...  MdB_Ulrike_Bahr
# 22  Geboren am 15. August 1965 in Bogazköy, Ankara...
# 23  Geboren am 15. Februar 1975 in Albstadt-Ebinge...   Thomas_Bareiss
# 24  Geboren am 19.November 1968 in Köln; zwei Kind...
# 25  Geboren am 22. Mai 1953 in Ludwigshafen; verhe...
# 26          Geboren am 5. Oktober 1963 in Eisleben...     SBarrientosK
# 27  Geboren am 1. Februar 1952 in Schwäbisch Gmünd...
# 28  Geboren am 16. Januar 1959 in Bremen; verheira...  matthiasbartke
# 29  Geboren am 4. September 1974 in Hamburg; evang...     soerenbartol
# 30  Geboren am 31. März 1958 in Stralsund.1976 Abi...   DietmarBartsch
# 31  Geboren am 3. Mai 1968.1984 Hauptschulabschlus...       baerbelbas
# 32  Geboren am 19. März 1987 in Vilsbiburg (Landkr...
# 33  Geboren am 31. Januar 1958 in Wanne-Eickel; ko...  berndbaumannafd
# 34          Geboren am 19. Januar 1959 in Wertheim...   MargareteBause
# 35          Geboren am 15. Oktober 1983 in Heidelb...        DerDanyal
# 36          Geboren am 11. Februar 1966 in Malatya...    LieblingXhain
# 37          Geboren am 19. September 1969 in Münst...        jensbeeck
# 38          Geboren am 23. Januar 1970 in Wiesbade...              NaN
# 39  Geboren am 19. Oktober 1981 in Nienburg an der...     MaikBeermann
# 40  Geboren am 28. Oktober 1956 in Magdeburg; evan...   Manfredbehrens
# 41  Geboren am 20. November 1960 in Karl-Marx-Stad...
# 42          Geboren am 8. Januar 1961 in Münster; ...   SybilleBenning
# 43  Geboren am 5. Juli 1972 in Osnabrück; aufgewac...
# 44          Geboren am 5. Februar 1972 in Reutling...  MarcBernhardAfD
# 45          Geboren am 28. September 1976 in Buchh...
# 46          Geboren am 8. Februar 1984 in Bernburg...      c_bernstiel
# 47          Geboren am 18. Juli 1978 in Hamburg; l...         lgbeutin
# 48  Geboren am 25. Dezember 1970 in Ratingen; römi...      Peter_Beyer
# 49          Geboren am 3. September 1979 in Böblin...      MBiadaczMdB

# %%
# save combined df
with open('abg_df.pickle', 'wb') as handle:
    pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)
